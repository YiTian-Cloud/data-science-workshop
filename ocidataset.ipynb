# %%
# %pip install -U "oracle-ads[data]"
print("done")
# Out:
# Requirement already satisfied: oracle-ads[data] in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (2.13.20)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (6.0.3)
# Requirement already satisfied: asteval>=0.9.25 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (1.0.6)
# Requirement already satisfied: cerberus>=1.3.4 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (1.3.7)
# Requirement already satisfied: cloudpickle>=1.6.0 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (3.1.1)
# Requirement already satisfied: fsspec>=0.8.7 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (2025.9.0)
# Requirement already satisfied: gitpython>=3.1.2 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (3.1.45)
# Requirement already satisfied: jinja2>=2.11.2 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (3.1.6)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (3.10.6)
# Requirement already satisfied: numpy>=1.19.2 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (2.3.3)
# Requirement already satisfied: oci>=2.148.0 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (2.161.0)
# Requirement already satisfied: ocifs>=1.1.3 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (1.3.2)
# Requirement already satisfied: pandas>=2.2.0 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (2.3.3)
# Requirement already satisfied: psutil>=5.7.2 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (7.1.0)
# Requirement already satisfied: python_jsonschema_objects>=0.3.13 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (0.5.7)
# Requirement already satisfied: requests in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (2.32.5)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (1.7.2)
# Requirement already satisfied: tabulate>=0.8.9 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (0.9.0)
# Requirement already satisfied: tqdm>=4.59.0 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (4.67.1)
# Requirement already satisfied: pydantic>=2.6.3 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (2.12.0)
# Requirement already satisfied: tenacity in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (9.1.2)
# Requirement already satisfied: httpx in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (0.28.1)
# Requirement already satisfied: datefinder>=0.7.1 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (0.7.3)
# Requirement already satisfied: fastavro>=0.24.2 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (1.12.0)
# Requirement already satisfied: htmllistparse>=0.6.0 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (0.6.1)
# Requirement already satisfied: openpyxl>=3.0.7 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (3.1.5)
# Requirement already satisfied: oracledb>=1.0 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (3.4.0)
# Requirement already satisfied: pandavro>=1.6.0 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (1.9.0)
# Requirement already satisfied: sqlalchemy<=1.4.46,>=1.4.1 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracle-ads[data]) (1.4.46)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from sqlalchemy<=1.4.46,>=1.4.1->oracle-ads[data]) (3.2.4)
# Requirement already satisfied: regex>=2017.02.08 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from datefinder>=0.7.1->oracle-ads[data]) (2025.9.18)
# Requirement already satisfied: python-dateutil>=2.4.2 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from datefinder>=0.7.1->oracle-ads[data]) (2.9.0.post0)
# Requirement already satisfied: pytz in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from datefinder>=0.7.1->oracle-ads[data]) (2025.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from gitpython>=3.1.2->oracle-ads[data]) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.2->oracle-ads[data]) (5.0.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from htmllistparse>=0.6.0->oracle-ads[data]) (4.14.2)
# Requirement already satisfied: fusepy in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from htmllistparse>=0.6.0->oracle-ads[data]) (3.0.1)
# Requirement already satisfied: html5lib in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from htmllistparse>=0.6.0->oracle-ads[data]) (1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from jinja2>=2.11.2->oracle-ads[data]) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from matplotlib>=3.1.3->oracle-ads[data]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from matplotlib>=3.1.3->oracle-ads[data]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from matplotlib>=3.1.3->oracle-ads[data]) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from matplotlib>=3.1.3->oracle-ads[data]) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from matplotlib>=3.1.3->oracle-ads[data]) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from matplotlib>=3.1.3->oracle-ads[data]) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from matplotlib>=3.1.3->oracle-ads[data]) (3.2.5)
# Requirement already satisfied: certifi in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oci>=2.148.0->oracle-ads[data]) (2025.10.5)
# Requirement already satisfied: cryptography<46.0.0,>=3.2.1 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oci>=2.148.0->oracle-ads[data]) (44.0.3)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=17.5.0 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oci>=2.148.0->oracle-ads[data]) (24.3.0)
# Requirement already satisfied: circuitbreaker<3.0.0,>=1.3.1 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oci>=2.148.0->oracle-ads[data]) (2.1.3)
# Requirement already satisfied: cffi>=1.12 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from cryptography<46.0.0,>=3.2.1->oci>=2.148.0->oracle-ads[data]) (2.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from python-dateutil>=2.4.2->datefinder>=0.7.1->oracle-ads[data]) (1.17.0)
# Requirement already satisfied: pycparser in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from cffi>=1.12->cryptography<46.0.0,>=3.2.1->oci>=2.148.0->oracle-ads[data]) (2.22)
# Requirement already satisfied: et-xmlfile in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from openpyxl>=3.0.7->oracle-ads[data]) (2.0.0)
# Requirement already satisfied: typing_extensions>=4.14.0 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from oracledb>=1.0->oracle-ads[data]) (4.15.0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from pandas>=2.2.0->oracle-ads[data]) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from pydantic>=2.6.3->oracle-ads[data]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from pydantic>=2.6.3->oracle-ads[data]) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from pydantic>=2.6.3->oracle-ads[data]) (0.4.2)
# Requirement already satisfied: inflection>=0.2 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from python_jsonschema_objects>=0.3.13->oracle-ads[data]) (0.5.1)
# Requirement already satisfied: Markdown>=2.4 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from python_jsonschema_objects>=0.3.13->oracle-ads[data]) (3.9)
# Requirement already satisfied: jsonschema>=4.18 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from python_jsonschema_objects>=0.3.13->oracle-ads[data]) (4.25.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from jsonschema>=4.18->python_jsonschema_objects>=0.3.13->oracle-ads[data]) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from jsonschema>=4.18->python_jsonschema_objects>=0.3.13->oracle-ads[data]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from jsonschema>=4.18->python_jsonschema_objects>=0.3.13->oracle-ads[data]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from jsonschema>=4.18->python_jsonschema_objects>=0.3.13->oracle-ads[data]) (0.27.1)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from scikit-learn>=1.0->oracle-ads[data]) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from scikit-learn>=1.0->oracle-ads[data]) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from scikit-learn>=1.0->oracle-ads[data]) (3.6.0)
# Requirement already satisfied: colorama in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from tqdm>=4.59.0->oracle-ads[data]) (0.4.6)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from beautifulsoup4->htmllistparse>=0.6.0->oracle-ads[data]) (2.8)
# Requirement already satisfied: webencodings in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from html5lib->htmllistparse>=0.6.0->oracle-ads[data]) (0.5.1)
# Requirement already satisfied: anyio in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from httpx->oracle-ads[data]) (4.11.0)
# Requirement already satisfied: httpcore==1.* in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from httpx->oracle-ads[data]) (1.0.9)
# Requirement already satisfied: idna in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from httpx->oracle-ads[data]) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from httpcore==1.*->httpx->oracle-ads[data]) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from anyio->httpx->oracle-ads[data]) (1.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from requests->oracle-ads[data]) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from requests->oracle-ads[data]) (2.5.0)
# Note: you may need to restart the kernel to use updated packages.
# done

# %%
import sys, ads, geopandas as gpd
from osgeo import gdal
print("Python:", sys.executable)
print("ADS:", ads.__version__)
print("GeoPandas:", gpd.__version__)
print("GDAL:", gdal.VersionInfo())
# Out:
# Python: C:\Users\ytian\miniconda3\envs\localds2\python.exe
# ADS: 2.13.20
# GeoPandas: 1.1.1
# GDAL: 3100300

# %%
# %pip install imbalanced-learn
# Out:
# Collecting imbalanced-learn
#   Using cached imbalanced_learn-0.14.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy<3,>=1.25.2 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from imbalanced-learn) (2.3.3)
# Requirement already satisfied: scipy<2,>=1.11.4 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from imbalanced-learn) (1.16.2)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from imbalanced-learn) (1.7.2)
# Requirement already satisfied: joblib<2,>=1.2.0 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from imbalanced-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\ytian\miniconda3\envs\localds2\lib\site-packages (from imbalanced-learn) (3.6.0)
# Using cached imbalanced_learn-0.14.0-py3-none-any.whl (239 kB)
# Installing collected packages: imbalanced-learn
# Successfully installed imbalanced-learn-0.14.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from ads.dataset.factory import DatasetFactory

url = ("https://earthquake.usgs.gov/fdsnws/event/1/query?"
       "format=csv&starttime=2024-01-01&endtime=2025-10-07"
       "&minmagnitude=2.5&minlatitude=32&maxlatitude=42.1"
       "&minlongitude=-125&maxlongitude=-114&orderby=time-asc")
ca_eq = pd.read_csv(url)

# normalize datetime columns (ADS expects tz-naive)
for c in ("time","updated"):
    if c in ca_eq.columns:
        ca_eq[c] = pd.to_datetime(ca_eq[c], utc=True).dt.tz_convert(None)

ds = DatasetFactory.from_dataframe(ca_eq)
fig = ds.plot_gis_scatter(lon="longitude", lat="latitude",
                          color="mag", size="mag",
                          title="California Earthquakes (M≥2.5)")
fig.show()
# Out:
# loop1:   0%|          | 0/4 [00:00<?, ?it/s]
# ERROR - Exception
# Traceback (most recent call last):
#   File "C:\Users\ytian\miniconda3\envs\localds2\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\ytian\AppData\Local\Temp\ipykernel_45088\3015247638.py", line 16, in <module>
#     fig = ds.plot_gis_scatter(lon="longitude", lat="latitude",
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ytian\miniconda3\envs\localds2\Lib\site-packages\ads\common\decorator\runtime_dependency.py", line 174, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
# TypeError: PandasDataset.plot_gis_scatter() got an unexpected keyword argument 'color'
# TypeError: PandasDataset.plot_gis_scatter() got an unexpected keyword argument 'color'

# %% [markdown]
# # OCI Data Science

# %%
# The Attrition Dataset
print("good")
# Out:
# good

# %%
# %pip install -U seaborn

# %%
import io
import warnings
import logging
import os
import ads
from ads.dataset.factory import DatasetFactory
from ads.common.auth import default_signer

import pandas as pd
import numpy as np
import seaborn as sns

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

warnings.filterwarnings('ignore')
logging.basicConfig(format='%(levelname)s:%(message)s', level=logging.ERROR)
print(f"done")
# Out:
# done

# %%
# %pip install -U "oracle-ads[data]" ocifs oci

# %%
"""
ads.set_auth(auth='resource_principal')
bucket_name="hosted_ds_datasets"
namespace="bigdatadatasciencelarge"
employees=DatasetFactory.open(
    "oci://{}@{}/synthetic/orcl_attrition.csv".format(bucket_name, namespace),
                              target="Attrition", storage_options={'config':{}, 'region':'us-ashubrun-1'})


employees.info()
employees.head()
"""

# %%
import pandas as pd
"""
url = "https://objectstorage.us-ashburn-1.oraclecloud.com/n/bigdatadatasciencelarge/b/hosted-ds-datasets/o/synthetic%2Forcl_attrition.csv"
df = pd.read_csv(url)
df.head()
"""
iris = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",
                   header=None, names=["sepal_len","sepal_wid","petal_len","petal_wid","species"])
iris.info()
iris.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sepal_len  150 non-null    float64
#  1   sepal_wid  150 non-null    float64
#  2   petal_len  150 non-null    float64
#  3   petal_wid  150 non-null    float64
#  4   species    150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
#    sepal_len  sepal_wid  petal_len  petal_wid      species
# 0        5.1        3.5        1.4        0.2  Iris-setosa
# 1        4.9        3.0        1.4        0.2  Iris-setosa
# 2        4.7        3.2        1.3        0.2  Iris-setosa
# 3        4.6        3.1        1.5        0.2  Iris-setosa
# 4        5.0        3.6        1.4        0.2  Iris-setosa

# %%
import ads

# %%
from ads.dataset.dataset_browser import DatasetBrowser
import pandas as pd

DatasetBrowser.list()
# Out:
# ['web', 'sklearn', 'seaborn', 'GitHub']

# %%
sklearn = DatasetBrowser.sklearn()
sklearn.list()
# Out:
# ['breast_cancer', 'diabetes', 'iris', 'wine', 'digits']

# %%
ds1 = sklearn.open('wine')
ds1.info()
ds1.head()
# Out:
# loop1:   0%|          | 0/4 [00:00<?, ?it/s]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
#  12  proline                       178 non-null    float64
#  13  target                        178 non-null    category
# dtypes: category(1), float64(13)
# memory usage: 18.5 KB
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline   target
# 0                          3.92   1065.0  class_0
# 1                          3.40   1050.0  class_0
# 2                          3.17   1185.0  class_0
# 3                          3.45   1480.0  class_0
# 4                          2.93    735.0  class_0

# %%
ds1.suggest_recommendations()
# Out:
#                                                                                                                                                                                              Code
# Message                                                        Variables     Suggested                         Action
# Strongly correlated with flavanoids(86.46%.)                   total_phenols Drop total_phenols                Drop total_phenols                                .drop_columns(["total_phenols"])
#                                                                                                                Drop flavanoids                                      .drop_columns(["flavanoids"])
#                                                                                                                Do nothing
# Strongly correlated with od280/od315_of_diluted_wines(78.72%.) flavanoids    Drop od280/od315_of_diluted_wines Drop flavanoids                                      .drop_columns(["flavanoids"])
#                                                                                                                Drop od280/od315_of_diluted_wines  .drop_columns(["od280/od315_of_diluted_wines"])
#                                                                                                                Do nothing

# %%
transformed_ds1 = ds1.auto_transform()
# Out:
# loop1:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
import os, sys, shutil, pathlib

print("Python:", sys.executable)
print("Conda prefix:", os.environ.get("CONDA_PREFIX"))
print("Conda default env:", os.environ.get("CONDA_DEFAULT_ENV"))
print("Is 'conda' on PATH?:", bool(shutil.which("conda")))
print("Kernel site-packages:", [p for p in sys.path if "site-packages" in p][:2])
print("Conda meta dir exists?:", pathlib.Path(sys.prefix, "conda-meta").exists())
# Out:
# Python: C:\Users\ytian\miniconda3\envs\localds2\python.exe
# Conda prefix: C:\Users\ytian\miniconda3\envs\localds2
# Conda default env: localds2
# Is 'conda' on PATH?: True
# Kernel site-packages: ['C:\\Users\\ytian\\miniconda3\\envs\\localds2\\Lib\\site-packages', 'C:\\Users\\ytian\\miniconda3\\envs\\localds2\\Lib\\site-packages\\win32']
# Conda meta dir exists?: True

# %%
# Patch ADS's expectation that display/SVG are in IPython.core.display
from IPython.display import display, SVG
import IPython.core.display as _core_disp
_core_disp.display = display
_core_disp.SVG = SVG

#%pip install -q graphviz pydot
# Make graphviz.Source tolerant if it was constructed with a Digraph
from graphviz import Source, Digraph

def _source_iter_pathed(self):
    src = getattr(self, "_source", "")
    if isinstance(src, Digraph):
        src = src.source  # use the DOT text
    for line in src.splitlines(keepends=True):
        yield line

Source.__iter__ = _source_iter_pathed
ds1.visualize_transforms()
# Out:
# (process:38608): Pango-CRITICAL **: 22:14:09.399: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:38608): Pango-CRITICAL **: 22:14:09.399: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:38608): Pango-CRITICAL **: 22:14:09.399: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:38608): Pango-CRITICAL **: 22:14:09.399: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:38608): Pango-CRITICAL **: 22:14:09.399: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:38608): Pango-CRITICAL **: 22:14:09.399: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:38608): Pango-CRITICAL **: 22:14:09.399: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:38608): Pango-CRITICAL **: 22:14:09.399: pango_font_description_get_family: assertion 'desc != NULL' failed

# %%
def _source_iter_pathed(self):
    src = getattr(self, "_source", "")
    if isinstance(src, Digraph):
        src = src.source  # use the DOT text
    for line in src.splitlines(keepends=True):
        yield line

Source.__iter__ = _source_iter_pathed
transformed_ds1.visualize_transforms()
# Out:
# (process:46172): Pango-CRITICAL **: 22:14:17.226: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:46172): Pango-CRITICAL **: 22:14:17.226: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:46172): Pango-CRITICAL **: 22:14:17.226: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:46172): Pango-CRITICAL **: 22:14:17.226: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:46172): Pango-CRITICAL **: 22:14:17.226: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:46172): Pango-CRITICAL **: 22:14:17.226: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:46172): Pango-CRITICAL **: 22:14:17.226: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:46172): Pango-CRITICAL **: 22:14:17.226: pango_font_description_get_family: assertion 'desc != NULL' failed

# %% [markdown]
# # Category encoder

# %%
transformed_ds1.head()
transformed_ds1['target'].value_counts()
transformed_ds1.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  flavanoids  \
# 0    14.23        1.71  2.43               15.6      127.0        3.06
# 1    13.20        1.78  2.14               11.2      100.0        2.76
# 2    13.16        2.36  2.67               18.6      101.0        3.24
# 3    14.37        1.95  2.50               16.8      113.0        3.49
# 4    13.24        2.59  2.87               21.0      118.0        2.69
#
#    nonflavanoid_phenols  proanthocyanins  color_intensity   hue  proline  \
# 0                  0.28             2.29             5.64  1.04   1065.0
# 1                  0.26             1.28             4.38  1.05   1050.0
# 2                  0.30             2.81             5.68  1.03   1185.0
# 3                  0.24             2.18             7.80  0.86   1480.0
# 4                  0.39             1.82             4.32  1.04    735.0
#
#     target
# 0  class_0
# 1  class_0
# 2  class_0
# 3  class_0
# 4  class_0

# %%
from ads.dataset.label_encoder import DataFrameLabelEncoder
ds_encoded = DataFrameLabelEncoder().fit_transform(transformed_ds1.to_pandas())
ds_encoded['target'].value_counts()
# Out:
# target
# 1    71
# 0    59
# 2    48
# Name: count, dtype: int64

# %%
# %pip install imbalanced-learn

# %%
from ads.dataset.helper import up_sample
ds_upsampled = up_sample(transformed_ds1, ['target'], sampler='default', feature_types=None)
ds_upsampled.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  flavanoids  \
# 0    14.23        1.71  2.43               15.6      127.0        3.06
# 1    13.20        1.78  2.14               11.2      100.0        2.76
# 2    13.16        2.36  2.67               18.6      101.0        3.24
# 3    14.37        1.95  2.50               16.8      113.0        3.49
# 4    13.24        2.59  2.87               21.0      118.0        2.69
#
#    nonflavanoid_phenols  proanthocyanins  color_intensity   hue  proline  \
# 0                  0.28             2.29             5.64  1.04   1065.0
# 1                  0.26             1.28             4.38  1.05   1050.0
# 2                  0.30             2.81             5.68  1.03   1185.0
# 3                  0.24             2.18             7.80  0.86   1480.0
# 4                  0.39             1.82             4.32  1.04    735.0
#
#
# 0  class_0
# 1  class_0
# 2  class_0
# 3  class_0
# 4  class_0

# %%
ds_upsampled[ds_upsampled['alcohol']==14.23]
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  flavanoids  \
# 0    14.23        1.71  2.43               15.6      127.0        3.06
#
#    nonflavanoid_phenols  proanthocyanins  color_intensity   hue  proline  \
# 0                  0.28             2.29             5.64  1.04   1065.0
#
#
# 0  class_0

# %%
ds_upsampled[''].value_counts()
# Out:
# class_0    71
# class_1    71
# class_2    71
# Name: count, dtype: int64

# %%
ds1['target'].value_counts()
# Out:
# target
# class_1    71
# class_0    59
# class_2    48
# Name: count, dtype: int64

# %% [markdown]
# # Split data for testing

# %%
data_split = transformed_ds1.train_validation_test_split(
    test_size=0.10,
    validation_size=0.10
)
train, validation, test = data_split
print(data_split)
# Out:
# (Train Data
# Shape of X:(144, 11)
# Shape of y:(144,), Validation Data
# Shape of X:(16, 11)
# Shape of y:(16,), Test Data
# Shape of X:(18, 11)
# Shape of y:(18,))

# %%
import seaborn as sns
from sklearn.datasets import load_iris
from ads.dataset.factory import DatasetFactory
data = load_iris()
iris_df = pd.DataFrame(data.data, columns=data.feature_names)
sns.set(style="ticks", color_codes=True)
DatasetFactory.from_dataframe(iris_df).call(lambda df: sns.pairplot(df.dropna()))
# Out:
# loop1:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline  # (optional in Jupyter)

# ---- sample data ----
df = pd.DataFrame(np.random.randn(1000, 4), columns=list('ABCD'))

# ---- plotting function ----
def ts_plot(df_in, figsize=(7, 7)):
    # build a matching datetime index
    ts = pd.date_range('2000-01-01', periods=len(df_in), freq='D')

    # work on a copy so we don't mutate the original
    df2 = df_in.copy()
    df2.index = ts

    # cumulative sum for a nicer time-series shape
    df2 = df2.cumsum()

    # plot
    fig, ax = plt.subplots(figsize=figsize)
    df2.plot(ax=ax)
    ax.legend(loc='best')
    ax.set_title('Cumulative Sum Time Series')
    ax.set_xlabel('Date')
    ax.set_ylabel('Value')
    plt.show()

# ---- EITHER call directly ----
ts_plot(df, figsize=(7, 7))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame(np.random.randn(1000, 4), columns=list('ABCD'))

def ts_plot(df_in, figsize=(7,7)):
    #ts= pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000',periods=1000))
    df2 = df_in.copy()
    ts = pd.date_range('2000-01-01', periods=len(df_in), freq='D')
    
    #df_in.set_index(ts)
    df2.index = ts
    df2 = df2.cumsum()

    fig, ax = plt.subplots(figsize=figsize)
    
   # plt.figure()
    df2.plot(ax=ax)
    ax.legend(loc='best')
    #plt.legend(loc='best')
    ax.set_title("Cumulative Sum Time Series")
    ax.set_xlabel('Date')
    ax.set_ylabel('Value')
    plt.show()

ts_plot(df, figsize=(7,7))

#ds = DatasetFactory.from_dataframe(df, target='A')
#ds.call(ts_plot, figsize=(7,7))

# %%
# %pip install oracle-ads[geo]

# %%
import inspect
print(inspect.signature(ds.plot_gis_scatter))
help(ds.plot_gis_scatter)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import inspect
# ----> 2 print(inspect.signature(ds.plot_gis_scatter))
#       3 help(ds.plot_gis_scatter)
#
# NameError: name 'ds' is not defined

# %%
import pandas as pd
from ads.dataset.factory import DatasetFactory

url = ("https://earthquake.usgs.gov/fdsnws/event/1/query?"
       "format=csv&starttime=2024-01-01&endtime=2025-10-07"
       "&minmagnitude=2.5&minlatitude=32&maxlatitude=42.1"
       "&minlongitude=-125&maxlongitude=-114&orderby=time-asc")
ca_eq = pd.read_csv(url)

# normalize datetime columns (ADS expects tz-naive)
for c in ("time","updated"):
    if c in ca_eq.columns:
        ca_eq[c] = pd.to_datetime(ca_eq[c], utc=True).dt.tz_convert(None)

ds = DatasetFactory.from_dataframe(ca_eq)
fig = ds.plot_gis_scatter(lon="longitude", lat="latitude")
fig.show()
# Out:
# loop1:   0%|          | 0/4 [00:00<?, ?it/s]
# ERROR - Exception
# Traceback (most recent call last):
#   File "C:\Users\ytian\miniconda3\envs\localds2\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\ytian\AppData\Local\Temp\ipykernel_20164\2091248137.py", line 17, in <module>
#     fig.show()
#     ^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'show'
# AttributeError: 'NoneType' object has no attribute 'show'

# %%
import pandas as pd
from ads.dataset.factory import DatasetFactory

url = (
    "https://earthquake.usgs.gov/fdsnws/event/1/query?"
    "format=csv"
    "&starttime=2024-01-01&endtime=2025-10-07"     # adjust dates
    "&minmagnitude=2.5"
    "&minlatitude=32&maxlatitude=42.1"             # CA lat range
    "&minlongitude=-125&maxlongitude=-114"         # CA lon range
    "&orderby=time-asc"
)
ca_eq = pd.read_csv(url)
ca_eq.head()

# 1) Load (already done in your notebook) and normalize datetime columns to naive UTC
for col in ("time", "updated"):
    if col in ca_eq.columns:
        s = pd.to_datetime(ca_eq[col], errors="coerce", utc=True)
        # drop timezone info, keep UTC clock time
        ca_eq[col] = s.dt.tz_convert(None)

print(ca_eq[["time"]].dtypes)  # should show datetime64[ns] (no timezone)

ds = DatasetFactory.from_dataframe(ca_eq)
fig = ds.plot_gis_scatter(
    lon="longitude",
    lat="latitude"
)
fig.show()
# Out:
# time    datetime64[ns]
# dtype: object
# loop1:   0%|          | 0/4 [00:00<?, ?it/s]
# ERROR - Exception
# Traceback (most recent call last):
#   File "C:\Users\ytian\miniconda3\envs\localds2\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\ytian\AppData\Local\Temp\ipykernel_51076\3455512748.py", line 30, in <module>
#     fig.show()
#     ^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'show'
# AttributeError: 'NoneType' object has no attribute 'show'
